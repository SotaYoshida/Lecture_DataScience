# %% [markdown]
# <a href="https://colab.research.google.com/github/SotaYoshida/Lecture_DataScience/blob/master/Python_chapter4_handling_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ファイル操作

# %% [markdown]
# この章では、google driveに保存されたテキストファイルやcsvファイル(excelファイル)をPythonで操作する簡単な方法を学習する。
#
# これまでの章では、データはリストとして既に与えられた状態から解析を行ったが、実際にデータを扱う際は既に誰かが作成した何らかのファイルをプログラムで読み込んで操作する必要がある。
#
#
# 以下では、テキストファイルとExcelファイル(csv,excel)を例にファイル操作の基礎を学習する。
