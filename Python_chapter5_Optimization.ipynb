# %% [markdown]
# <a href="https://colab.research.google.com/github/SotaYoshida/Lecture_DataScience/blob/master/Python_chapter5_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #最適化問題の基礎

# %% [markdown]
# ## 最適化問題としての最小二乗法

# %% [markdown]
# ##代表的な最適化手法

# %% [markdown]
# ### 勾配降下法

# %% [markdown]
# ### Adam
