# %% [markdown]
# <a href="https://colab.research.google.com/github/SotaYoshida/Lecture_DataScience/blob/master/Python_misc_ObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 機械学習を用いた画像認識・物体検知の概要

# %% [markdown]
# (編集中)

# %% [markdown]
# ## 畳み込みニューラルネットワーク (Convolutional Neural Network, CNN)

# %% [markdown]
# CNNとは、畳み込み層と呼ばれるレイヤーを持つニューラルネットワークで、
# 画像認識や物体検知において高い性能を発揮します。
#
# 以下ではその概要と、簡単な実装例を紹介する。 (編集中)

# %% [markdown]
# # YOLOを用いた物体検知
#
# YOLOはYou Only Look Onceの略.
# You Only Live Once（人生は一度きり）をもじったタイトルらしい。

# %%
import platform
import cv2
import matplotlib.pyplot as plt
import os

# %%
wdir = "pictest" #working_directoryの名前を適当に決める
os.mkdir(wdir) #そのディレクトリを作成
os.chdir(wdir) #そのディレクトリに移動

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.
# darknet  yolov3.weights

# %%
os.chdir('darknet')
# !make #darknetをビルドする

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights

# %% [markdown]
# 犬、自転車,トラックが写っているサンプル画像で物体検知してみる。

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights 'data/dog.jpg'

# %%
img_in = cv2.imread('data/dog.jpg')
img_out = cv2.imread('predictions.jpg')
plt.figure(figsize=[20,10])
plt.subplot(121);plt.imshow(img_in[:,:,::-1]);plt.axis('off')
plt.subplot(122);plt.imshow(img_out[:,:,::-1]);plt.axis('off')
# Out:
# (-0.5, 767.5, 575.5, -0.5)

# %% [markdown]
# darknet/data

# %%
#サンプル画像の一覧
# !ls data/*jpg
# Out:
# data/dog.jpg	data/giraffe.jpg  data/kite.jpg    data/scream.jpg
# data/eagle.jpg	data/horses.jpg   data/person.jpg

# %% [markdown]
# 他のデータ

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights 'data/person.jpg'
img_in = cv2.imread('data/person.jpg')
img_out = cv2.imread('predictions.jpg')
# Out:
# data/person.jpg: Predicted in 25.928279 seconds.
# horse: 100%
# dog: 99%
# person: 100%

# %%
plt.figure(figsize=[20,10])
plt.subplot(121);plt.imshow(img_in[:,:,::-1]);plt.axis('off')
plt.subplot(122);plt.imshow(img_out[:,:,::-1]);plt.axis('off')
plt.show()
plt.close()
