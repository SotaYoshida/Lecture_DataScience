# %% [markdown]
# <a href="https://colab.research.google.com/github/SotaYoshida/Lecture_DataScience/blob/master/Python_chapter1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pythonの基本 その２:
#
#
# ### リスト
#
# 実際にいろんなデータを扱う際には、  値や変数をまとめて処理したくなります。
# こうしたときに必要になるのがリストです。
#
# リスト型は、値や変数などを括弧[ ]で括り、カンマで区切ることで作ることができます。
#
# ```[ 1.0, 2.0, 3.0]```
# また変数にリストを代入することもできます

# %%
a=[ 1.0, 2.0, 3.0]
print(a)
print(type(a))
# Out:
# [1.0, 2.0, 3.0]
# <class 'list'>

# %% [markdown]
# 文字列のリストも作れます
#
#
#
# ```["a", "bbb", "cc"]```

# %% [markdown]
# リストに入っている要素の数は、len関数(lengthの略)で見ることができます。

# %%
len(a)
# Out:
# 3

# %% [markdown]
# 当然、長さに名前をつけて適当な変数に突っ込むこともできます。
#
# ```ln_a = len(a)```

# %% [markdown]
# 文字列と値を組み合わせたようなリストも作ることができます。
# (例：名前、身長、体重)
# ```["Aさん", 178, 66]```
#
# また、これを拡張して、入れ子にすることもできます。
#
# ``` [ ["Aさん", 178,66], ["Bさん", 180, 70] ]```

# %% [markdown]
# リストの中の要素にアクセスするときは、括弧[整数]で"番地"を指定します。
# このときの番地(あるいは座標といっても良いですが)を指定する整数のことをインデックス(index)と呼びます。
# Pythonでは、要素にアクセスするためのインデックスは１からではなく、0からカウントします。

# %%
print(a[0]); print(a[1]); print(a[2])
# Out:
# 1.0
# 2.0
# 3.0

# %% [markdown]
# ですので、a[3]にアクセスしようとすると、

# %%
print(a[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-5451d47c444b> in <module>()
# ----> 1 print(a[3])
#
# IndexError: list index out of range

# %% [markdown]
# list index out of range (リストのインデックスが用意された範囲(range)を逸脱している)というエラーが出ます。
#
#
# 慣れないうちは変に思うかもしれませんが、これはプログラミング言語の仕様によるもので、Pythonの他にもC/C++なども0からカウントします。
#
# (ちなみにFORTRAN, R, Julia, Lua, BASICなどは1からカウントします。)
#
# こうした0-based indexingと呼ばれる言語の利点としては、負のインデックスが使えることです。

# %%
print(a[-1])
print(a[-2])
# Out:
# 3.0
# 2.0

# %% [markdown]
# [-1]でアクセスすれば末尾の要素に、[-2]番目の要素は後ろから二番目といった具合です。
#
# これは長いリストを作って「えっとこれ前から何番目の要素だったっけ。。。？」というときに、後ろから３番目の要素をサクッと取得できるのが便利なときもあります。

# %% [markdown]
# **練習1**
#
#
# 1.   [+コード]でセルを以下に追加し、下のリストを作成する
# ```tmp = [ ["Aさん", 178,66], ["Bさん", 180, 70] ]```
# 2.    ```tmp[i][j]```のi,jに可能な整数を入れて、Aさんの身長、Bさんの体重などをprint関数で表示してみましょう。
#
# 3.   2.と同じことを、負のインデックスを駆使してやってみましょう。
#
#
#
# ---
#
# #### リスト同士の演算や要素の追加
#
# ２つのリストを結合することもできます。

# %%
a=[1,3] ; b=[2,4]
a+b
# Out:
# [1, 3, 2, 4]

# %% [markdown]
# リストにあとから要素を加えたくなるときもあります.
# そんなときは ```append```関数 か ```+=```　を使います。

# %%
A = [ "Aさん", 178,66] 
A.append("O型")
print(A)

B = [ "Bさん", 180,70] 
B += ["A型"]
print(B)
# Out:
# ['Aさん', 178, 66, 'O型']
# ['Bさん', 180, 70, 'A型']

# %% [markdown]
# 入れ子のリストを作るときは

# %%
data = [ ]
data +=  [ ["Aさん", 178,66] ]
data +=  [[ "Bさん",180,70]  ]
print(data)
# Out:
# ['Aさん', 178, 66, 'Bさん', 180, 70]

# %% [markdown]
# とします。
# += で要素を追加するときは一番外側の[ ]に囲まれたものを左辺の変数に加えると覚えておけば、リストを追加したいときに［ ］が二重に必要な理由がわかるかと思います。

# %% [markdown]
#  (*リストに似た型としてタプル()と辞書{}がありますが、集中講義では扱わないため省略します。そのうち追記します。)

# %% [markdown]
# ### for文
#
#
# ### While文
#
#
# ### 条件分岐
#
#
# ### 例外処理
