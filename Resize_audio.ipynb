# %% [markdown]
# <a href="https://colab.research.google.com/github/SotaYoshida/Lecture_DataScience/blob/master/Resize_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Google colabが初めての方へ
#
# 1. gmailアカウントでログインしてください
# 2. コード(灰色の部分を)上から実行(再生マークを押すか、セルにフォーカスを当ててCtrl+Enter (mac:command+Enter)してください

# %% [markdown]
# #### Google driveをマウントする
# 1. 以下を実行し、出てくるURLに遷移
# 2. authorization codeをコピーし枠内に貼り付けてEnterを押す  (Google colabからgoogle driveのファイルにアクセスできるようになります)

# %%
from google.colab import drive
drive.mount('./gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at ./gdrive

# %% [markdown]
# `./dgrive/My Drive`がgoogle driveでいうところのマイドライブに相当します。
# たとえば、マイドライブの直下にmp3というディレクトリがあって、その中にJugyo1.mp3というファイルがあったとします。
# すると、そのファイルへのpathは `./gdrive/My Drive/mp3/Jugyo1.mp3`となり、このようにファイルの住所が指定します。  *Google colabでは2バイト(全角)や空白も問題なくサポートしていますが、ファイル名はやはり半角にするのがおすすめです。
#
#
# #### ファイルの参照やその他の使い方
#
# Google Colab.ではターミナルで使用するコマンドの先頭に!をつけることで実行できます。
# つまり、リストの参照をしたいときは!lsとすればよく、ディレクトリを新たに作成したいときは!mkdirといった具合です.

# %%
# !ls ./gdrive/My\ Drive/mp3/*mp3 ## mp3ディレクトリ内のmp3で終わるファイルの一覧を表示するコマンド
# Out:
# ls: cannot access './gdrive/My Drive/mp3/*mp3': No such file or directory

# %% [markdown]
# 圧縮したいファイルがgoogle drive上にあることを確認できたら、以下のコードを実行します。

# %%
# !pip install pydub #pydubのインストール
from pydub import AudioSegment                                                                                                 
import glob
import sys

ibit = "128k"  ### bitrateを指定 "64k", "128k", "256k"あたりで試すのがおすすめです
inpf = "引用符内でinput file名を入力してください"

#例:
#inpf = './gdrive/My Drive/01 ドラえもん.mp3'

sound = AudioSegment.from_file(inpf)

oupf= inpf.replace(".mp3", "resized_"+str(ibit)+".mp3")   ##Currently, the code only supports mp3.                                                                       
sound.export(oupf, format="mp3", bitrate=ibit)

#'''複数一気にやりたい場合は以下のように全ファイルをリストに突っ込んでループを回せばよい'''
#inps = glob.glob("./gdrive/My Drive/mp3/*.mp3") ### 左は当該のフォルダ内のすべてのmp3ファイルを変換する場合                                                                                 
#for inpf inps:                                                                                                                                                          
#    sound = AudioSegment.from_file(inpf)                                                                                                                                
#    sound.export(oupf, format="mp3", bitrate="128k")
# Out:
# ...
# '複数一気にやりたい場合は上 args からsound.exportまでの行をコメントアウトし、以下のコメントアウトを外す'
