# %% [markdown]
# <a href="https://colab.research.google.com/github/SotaYoshida/Lecture_DataScience/blob/master/Python_chapter2_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Googleのアカウントにログインした状態で使用してください.

# %% [markdown]
# # ライブラリ/パッケージ/モジュールとデータの可視化(Matplotlib)
#
# Pythonでは(他のプログラミング言語と同様)特定の作業がパッケージ化されたプログラム群が用意されていて、これらをライブラリ,パッケージ,モジュールなどと呼びます*。
# その多くはGitHub上で開発・公開されていて、簡単にインストールしたり、インポートして使うことができますし、
# 質の高いものは言語に標準で組み込まれているため、以下のように簡単に使うことができます。
#
# *授業で使うノートブックでは、ライブラリやモジュール、パッケージという名前が混在しています。
# より正確な定義としてはライブラリ,パッケージ,モジュールの順により上位の集合を指すようですが、境界はあいまいな印象です。
#
#
# ---
#
# たとえばmathという名前のモジュールをインポートする際には

# %%
import math

# %% [markdown]
# とします。簡単ですね。それ以外の使い方は順次見ていくことにしましょう。
# 上でmathをインポートすると、数学で多用される$\pi$,対数関数log(),log10()、指数関数exp,三角関数sin,cosなどを使うことができます。

# %%
print(math.log(2.0))
print(math.log10(2.0))
print(math.exp(2.0))
print(math.pi)
print(math.sin(math.pi))

# %% [markdown]
# 注:sin(π)は厳密に0になるべきですが[chapter1_Introduction1]で述べたように、実数が有限の精度なので微小な量0からずれています

# %% [markdown]
# ---
# 以降では、matplotlibと呼ばれる(MATLABにルーツを持つ)モジュールを使って、各種のグラフを作成する方法を見ていきましょう.
#
# matplotlibは様々なグラフが描ける一方で、少々テクニカルな部分が多いので、
# 細かい部分は「こういうおまじないを唱える(書くと)こうなる」というざっくりとした理解で大丈夫です。
#
# はじめはネットに転がっている誰かが書いたコードを少しずつ流用し、自分の目的のためにどうすれば良いか[類推]しながら改良していって、自分の描きたいグラフに近づけていくのが良いでしょう。(私も未だに諳んじるのは難しく、過去の自分が作成したコードを流用して作図しています。)
#
# 慣れてくるといろんな図を作ったり、細かいところにこだわったりしたくなります。
# そんなときは以下のチートシートが役に立ちます.
# https://github.com/matplotlib/cheatsheets
# 日本語で書かれたものでオススメなのは以下の記事です
# https://qiita.com/skotaro/items/08dc0b8c5704c94eafb9

# %% [markdown]
# ## Python(Matplotlib)を用いた作図

# %% [markdown]
# さて、まずはライブラリをいくつかインポートしておきましょう。

# %%
from matplotlib import pyplot as plt ## matplotlib内のpyplotをインポートする。 ただし、pyplotだと名前が長いので plt　という名前で使えるようにする(as plt)
# !pip install japanize-matplotlib ## matplotlibは標準だと日本語が文字化けして豆腐のようになってしまうので、日本語を扱えるようにするためのライブラリをインストールします。
import japanize_matplotlib ##インストールしたライブラリが使えるようにインポートしておく
import numpy as np ## ついでにnumpyもインポートしておく。

# %% [markdown]
# ### 棒グラフ

# %% [markdown]
# Aさんのセンター試験の得点をリスト(括弧[ ]内に、数字カンマで区切る)に格納します。
# 順番(各科目の名前(ラベル))は、国語,英語,数IA,数IIB,化学,物理,世界史として...

# %%
data = [152, 170, 82,85,79,92,88]
label = ["国語","英語", "数IA", "数IIB", "化学", "物理", "世界史"]
total = sum(data)
print("合計得点は", total, "点で、得点率は"+str("%6.1f" % (100* total/900))+"%です")

# %% [markdown]
# Aさん優秀ですね。これを棒グラフにでもしてみましょう。

# %%
plt.figure(figsize=(7,2)) 
plt.bar(label,data,align='center',width=0.5,color="red") 
plt.xlabel("各科目"); plt.ylabel("Aさんの得点") 
plt.show() 
plt.close()

# %% [markdown]
# 棒グラフが描けたでしょうか。それぞれの行の意味を順に説明します。
# * 1行目: ```plt.figure(figsize=(7,2))  ```
# これは、matplotlib内のfigureという関数を読み込んで、図を描くキャンバスを用意しています。
# 今matplotlibモジュール内のpyplotというモジュールをpltという名前でインポートしましたので、
# plt.figureというのは、pyplot内のfigureという関数を使うことを意味します。
# 関数を使う際には原則として[引数(ひきすう)]が必要になりますが、ここでは```figsize=(7,2)```という引数を指定しました。
# figsize=(横,縦)で大きさが指定できます。 -> **figsizeを変えて試してみましょう**
#
# * 2行目: ```plt.bar(label,data,align='center',width=0.5,color="red") ```
# pyplot内のbarという関数(棒グラフを描く関数)を使っています。
# 1つめの引数はx軸上の値(あるいは位置)です。(数値以外のときは整数値にしてくれる)
# 2つめの引数はy軸に対応する値です。
#
# * 3行目: ```plt.xlabel("各科目"); plt.ylabel("Aさんの得点")  ```
# ここではx軸とy軸のデータの種類(ラベル,labelと呼びます)を指定しています。
#
# * 4行目: ```plt.show()```
# それまでに指定した条件で絵を描いて表示する(show)
#
# * 5行目: ```plt.close()  ```
# キャンバスを閉じる。とくに一つのプログラムで複数絵を描くときはこれを書きましょう。(closeしないと、機械にはどこまでがどのグラフのための指示かわからず、意図した絵になりません。)

# %% [markdown]
# ####  **練習**
# 国語と英語の得点を100点満点に換算し、いくつかの得点や棒グラフの色を変えてプロットしてみましょう。

# %% [markdown]
# ---

# %% [markdown]
# ### 円グラフ

# %% [markdown]
# 世の中には多くの円グラフの誤用が溢れています。とくにワイドショーなんかを見ていると、総和が100%になっていなかったり、それぞれの値と円に対して占める割合が誤っていたりと、ひどい有様です。
# 他にも、奥行方向に傾いた円グラフも誤った印象を与えます。
# このように、円グラフというのは作成する際に注意が必要ですし、作成した円グラフがおかしいと「私は教養のない人です」と言っているようなもので大変恥ずかしい思いをします。
#
# というか...円グラフにしなきゃいけないデータってあるんでしょうか？
# 帯グラフなどのほうがよっぽど量の比較にも向いていますし...あれ、無くない？
# ということで円グラフはナシにしましょう。

# %%
#どうしても円グラフが描きたい方へ (下のコードを適当にいじって遊んでみてください)
tlabels = ["Aと答えた人","Bと答えた人","Cと答えた人"]
ratio = [513,142, 249]
color = ["blue","red","orange"]
plt.figure(figsize=(4,4)) 
plt.pie(ratio,labels=tlabels,counterclock=False, startangle=90,autopct="%.1f%%")#labels=tlabelsは、 pie()関数の中のlabelsという引数にtlabelsを突っ込むという意味
plt.show()
plt.close() 
# counterclockは反時計回りのオプションをFalse(偽)とするのでつまり時計回り(回りくどいな...)
# startangleは円グラフの始点を、x軸から見て何度のところにとるかで、今は90度(つまり12時の方向)と設定.
# autopctは「値を%表記に直せ」というオプションで、 %.1f%%は小数点以下1桁まで出力しなさいという命令.

# %% [markdown]
# #### 2次元データのプロット : plot
#
# 説明変数xと目的変数yがあって、とくに**xに対するyの振る舞い**に興味がある場合。
#
# たとえば、日付(=x)に対するコロナウイルス感染者(y)の推移など。
#
# ここでは、WHOのSituation Reportが初めて発表された1月20日をｘ=0として、1ずつ増やすことにします。
# データが無い日の値は0ではなくNone(値なし)にすることに注意

# %%
# 感染者数と重傷者数
y= [282,314,None,581,846,
    1320,2014,2798,4593,
    6065,7818,9826,11953,14557,
    17391,20630,24554,28276,31481,34886,
     37558.40554,43103,45171] #2月13日までのデータ

y_sev=[51,51,None,96,177,237,324,461,976,1239,
       1370,1527,1795,2110,2296,2788,3219,3859,4821,6101,6188,6484,7333,8304]

plt.figure(figsize=(12,4)) 
plt.xlabel("1月20日以降の経過日数")
plt.plot(range(len(y)), y, label="世界全体での新型コロナウイルス感染者数",color="red")
plt.legend() ##凡例(線や点等の説明)を描画する
plt.show()
plt.close() 

plt.figure(figsize=(12,4)) 
plt.xlabel("1月20日以降の経過日数")
plt.yscale("log") ## y軸を対数スケールに変換
plt.plot(range(len(y)), y, marker="x",label="世界全体での新型コロナウイルス感染者数",color="red") ## markerの値を指定すれば、線だけじゃなく点を描くことも出来る。
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# (余談: もともとこの部分のコードは2020年2月上旬の集中講義用に書いたのですが、この頃は日本で感染拡大が起きて、オンライン授業になるなどとは想像できていませんでした。何が起こるか分かりませんね。)

# %% [markdown]
# 注意としては、plot関数は、x軸用のデータとy軸用のデータの数が合っていないと、エラーを起こします。
# 一緒にしているはずなのにエラーが出る。。。と言う場合は、

# %%
len(y)

# %% [markdown]
# などを実行してリストの長さ(入っている要素の数)をチェックしてみましょう。カンマがピリオドになるなどして、意図しない個数の要素をもつリストになっているかもしれません。
# 例: (意図したリスト) [2,3,5]　(間違えて作ったリスト) [2.3,5] ←長さ2のリスト
#
#
# **練習**: 「matplotlib marker」でWeb検索してみて、どんな形状のmarkerが使えるか調べてみましょう。
# その中から"x"(☓印)以外の好きなシンボルを選んで上のグラフをプロットしてみましょう。

# %% [markdown]
# ---

# %% [markdown]
# #### 2次元データのプロット: scatter(散布図)
#
# xとy、２つの量があって、どちらにも興味がある、あるいは両者の間の相関に興味がある場合、
# 散布図を描くと、見通しやすくなることが多いです。
#
# 以下では、2017年の宇都宮の平均気温とアイスクリームの消費量の相関を見てみましょう。
# 気温・アイスクリームの消費量ともに、1月から12月に順番にリストに入れていくことにします。

# %%
x= [3.1, 4.3, 6.6, 13.2, 19.1, 20.9, 26.4, 25.1, 21.9, 15.7, 9.6, 3.8]
y= [568, 572, 804, 833, 930, 965, 1213, 1120, 835, 540, 451, 502]

plt.figure(figsize=(4,4)) 
plt.title("宇都宮市") ## 図にはタイトルをつけることができます
plt.xlabel("平均気温 (℃)")
plt.ylabel("世帯あたりのアイスクリム・シャーベットの消費金額 (円)")
plt.scatter(x,y)
plt.show()
plt.close()

# %% [markdown]
# 相関はDS入門で既に勉強して(?)いたり、あとの章でPythonを使って復習(?)するので、相関係数などの情報を含んだもう少しかっこいい図を作ってみましょう。
#
# *学科・クラスなどに依ります。

# %%
x= np.array(x); y= np.array(y)## 注1　
r = np.corrcoef(x,y) ## x,yの配列間の相関行列を計算します 
corrcoef=r[0,1] ## 行列の非対角要素が相関係数です。 r[0,1] # 0行目1列の値

def seasoncolor(month): #季節ごとに適当に色を塗ってみましょう
    if month <= 2 or month ==12:
        return "blue"
    elif 3 <= month <=5:
        return "green"
    elif 6 <= month <=8:
        return "red"
    elif 9<= month <=11:
        return "orange"
    return tcol

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)  ## 注2
ax.set_facecolor("#D3DEF1")
ax.set_title("宇都宮市")
ax.set_xlabel("平均気温 (℃)")
ax.set_ylabel("世帯あたりのアイスクリム・シャーベットの消費金額 (円)")
ax.grid(True,axis="both",color="w", linestyle="dotted", linewidth=0.8)
for i in range(len(x)):
    tcol=seasoncolor(i+1)
    ax.scatter(x[i],y[i],marker="o",s=10,color=tcol,zorder=20000,alpha=0.7)
    ax.text(x[i],y[i],str(i+1)+"月",color="k",fontsize=8)
ax.text(0.1,0.9, "r="+str("%5.2f" % corrcoef), transform=ax.transAxes,fontsize=12)
plt.show()
plt.close()

# %% [markdown]
# ##### 注1: x,yのデータを numpy.array()という型に変換しました.
# 今の場合はnumpy.array()にする必要性はないのですが、こうしておくと数学的な処理(ベクトル積,行列操作など)が高速・便利になるため、[数値を格納したリストは常にnp.arrayに変換して使う]と慣れるまでは考えてもよいかもしれません。
# たとえばx軸の気温を絶対温度(ケルビン)に直したい時、リストのままでは、

# %% [markdown]
# 以下はエラーになります

# %%
x= [3.1, 4.3, 6.6, 13.2, 19.1, 20.9, 26.4, 25.1, 21.9, 15.7, 9.6, 3.8]

print(x - 273.15 )

# %% [markdown]
# ので、各要素に-273.15を加える必要がありますが、気温のリストをnp.arrayにしておけば

# %%
import numpy as np 
print(np.array(x) -273.15)

# %% [markdown]
# とするだけで、全ての要素に-273.15を加えたnp.arrayを返します。

# %% [markdown]
# #####  注2:

# %% [markdown]
# axという見慣れないものが導入されました。axは、plt.figure()で用意したキャンバスの上に、
# 作業領域を指定するための関数で、たとえばキャンバスを四分割して、似たようなグラフを4つ同時に描いたりするのに便利です。
#
# ただし、axなどを使いこなすのは少々テクニカルな点も多いので、よくわからない部分はとりあえず飛ばし読みで構いません。慣れてくると、その便利さに気がつくはずです。
#
# 細かい図の書き方は追々、一緒に勉強していきましょう.

# %% [markdown]
# #### Google Colab.上で作ったグラフの保存
#
# プログラムを実行して絵を描けるようになったら、
# 次にそれを保存して、レポートに貼り付けたり、誰かに送ったりする必要が出てくると思います。
#
# Google Colab.では、同じGoogleのサービスであるGoogle drive上にファイルを保存したり(無料版で15GBまで)保存したファイルを他人と共有することができます。
#
# 以下の2行を実行。

# %%
from google.colab import drive  
drive.mount('./gdrive')

# %% [markdown]
# すると、(複数アカウントを所持している方はアカウントの選択をすると)URLが出てきますので、それをクリックしてGoogle Drive File SystemにGoogle Driveの操作権限を許可します。
#
# すると、**[このコードをコピーし、アプリケーションに切り替えて貼り付けてください]。**というメッセージが出ますので、Enter your authorization code:という欄にコードを貼り付けます。

# %% [markdown]
# 次に、Googledriveに図を保存する用にフォルダを作っておきましょう

# %%
# !mkdir  'gdrive/My Drive/Colab_pic' ### Google driveのマイドライブ(driveを開くと最初に開くフォルダ)上にColab_picという名前のフォルダを作成します。

# %% [markdown]
# 上のコードを実行後にエラーが出ていなければ、Google driveを開いて(右上のアイコンからアカウントの設定に飛んで、右上にある9つの点のマークを押すと...Gmailなどと一緒にドライブが見つかるはず)見ると、Colab_picというディレクトリが作成されているかと思います。

# %% [markdown]
# 一度フォルダを作ってしまうと、２回目以降は上のコードを実行しても
# 「既にフォルダありますよ！！」という旨のエラーがでますのでノートを開くたびに実行する必要はありません。

# %% [markdown]
# これで準備ができました。
# 試しに以下のコードを実行して図を保存してみましょう。

# %%
### 先程の図
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(1,1,1)  
ax.set_facecolor("#D3DEF1")
ax.set_title("宇都宮市")
ax.set_xlabel("平均気温 (℃)")
ax.set_ylabel("世帯あたりのアイスクリム・シャーベットの消費金額 (円)")
ax.grid(True,axis="both",color="w", linestyle="dotted", linewidth=0.8)
for i in range(len(x)):
    tcol=seasoncolor(i+1)
    ax.scatter(x[i],y[i],marker="o",s=10,color=tcol,zorder=20000,alpha=0.7)
    ax.text(x[i],y[i],str(i+1)+"月",color="k",fontsize=8)
ax.text(0.1,0.9, "r="+str("%5.2f" % corrcoef), transform=ax.transAxes,fontsize=12)
plt.savefig("./gdrive/My Drive/Colab_pic/scatter_Utsunomiya_ice.pdf") #####  ここがさっきと違います！ 
## scatter_Utsunomiya_ice.pdf部分を適当なファイル名に変更してみましょう。
## 
plt.close()

# %% [markdown]
# Google drive上の指定したフォルダに、ファイルが作られたでしょうか？

# %% [markdown]
# matplotlibは指定した拡張子で描画してくれるので色々試してみましょう(.jpg,.pdf,.eps,.pngなど)
#
# (余談):スライドに載せる画像は可能な限り、ラスタ形式ではなくベクタ形式(pdfやeps)がおすすめです。
# (それか、高解像度でjpegやpngを作ってスライドで使って、誰かにスライドを渡すときは軽量化する)
# プレゼンで図が滲んでいるスライドを見せていると「あぁ配慮が足りないんだな」と思われて損をしてしまうかもしれません。
# 論文でラスタ画像を使う場合は「トンデモ論文だと思われて誰にも読まれない危険性」を理解して使いましょう。

# %% [markdown]
# #### 練習
# これまでの(棒グラフ,円グラフ,１次元図,散布図)の4つのグラフを描画したコード部分で、
# データを自由に足してみながら、plt.show()を書き換えてファイルに出力してみましょう。

# %% [markdown]
# ## gifアニメーションの作成

# %% [markdown]
# 「なんだこの程度ならExcelでも簡単にできるじゃん...」と思った皆さんのために、もう少し凝ったことをやってみましょう。
# gifアニメーション(パラパラ漫画)を作ってみましょう。
#
# 以下のリンクに、x軸をGDP,y軸を24歳から35歳の女性の平均就学年数としたグラフを画像ファイル(png)にしたものを公開しました。(もともとのデータはFACTFULNESSから来ているのでライセンスフリーです)
# https://drive.google.com/drive/folders/1E0H1CP_r8kFJPqtq-_sYr1-PNl-BUAXp?usp=sharing
#
#
# 1.   まずこれをダウンロードしてください。
# 2.   (たぶん)ZIP形式でダウンロードされるので、解凍してください
# 3.   解凍したフォルダを自身のGoogle Driveの好きな場所にアップロードしてください

# %% [markdown]
# たとえば私のようにGoogle DriveのマイドライブのAdDS2020というフォルダの下に、GDPvsWomenInSchoolというフォルダを置いたとします
#
# 参考スクリーンショット:
# ![](https://drive.google.com/uc?export=view&id=10y8NFw53P_Z_SBHlf1kxbCGR9MCyVYoC)
#
# *以下のコードを修正せずに使いたければ、Google Driveのマイドライブ直下に```AdDS2020```というフォルダを作成し、その下に```GDPvsWomenInSchool```をアップロードすれば可能です.

# %% [markdown]
# 年代ごとに別々になったたくさんのグラフを、1つのパラパラ漫画にまとめてみましょう

# %% [markdown]
# まだの場合は、google driveをマウントします

# %%
from google.colab import drive
drive.mount('./gdrive')

# %% [markdown]
# 先程のグラフがgoogle driveに保存されているかどうかは、以下のコマンドで確認できます(アップロードして直後はファイルが見つからないことがあります)

# %%
# !ls  ./gdrive/'My Drive'/AdDS2020/GDPvsWomenInSchool/*.png

# %% [markdown]
# AdDS2020/GDPvsWomenInSchool/の部分は皆さんのフォルダ名に適宜変更してください.
#
# pngファイルをまとめてgifにするコードは以下のとおりです。(処理にしばし時間がかかります)

# %%
from PIL import Image
import glob

files = sorted(glob.glob('./gdrive/My Drive/AdDS2020/GDPvsWomenInSchool/GDPvsWomen*.png')) ##まとめたいpngをワイルドカードで指定
images = list(map(lambda file: Image.open(file), files))

oupf = './gdrive/My Drive/AdDS2020/GDPvsWomen.gif' ##出力名と保存場所を指定する
images[0].save(oupf, save_all=True, append_images=images[1:], duration=400, loop=0)

# %% [markdown]
# エラーが出なければおそらく変数```oupf```で指定した場所に、gifファイルが生成されていると思います。
# [ファイルへのリンク](https://drive.google.com/file/d/1Y4EkRP3U-aUcziBOoHyxuBZWbT7ZGL-k/view?usp=sharing)
# 私の作成例は以下のとおりです
# ![](https://drive.google.com/uc?export=view&id=1Y4EkRP3U-aUcziBOoHyxuBZWbT7ZGL-k)
